# %%
import pandas as pd

# %%
df=pd.read_csv("World University Rankings.csv")

# %%
df
# Out:
#                                        name  scores_teaching  scores_research  \
# 0                      University of Oxford             96.6            100.0
# 1                       Stanford University             99.0              NaN
# 2     Massachusetts Institute of Technology             98.6             96.2
# 3                        Harvard University             97.7              NaN
# 4                   University of Cambridge             95.8            100.0
# ...                                     ...              ...              ...
# 2668                       Zarqa University              NaN              NaN
# 2669                     Zhetysu University              NaN              NaN
# 2670  Zhytomyr Polytechnic State University              NaN              NaN
# 2671      Ziane Achour University of Djelfa              NaN              NaN
# 2672                    Ziauddin University              NaN              NaN
#
# ...

# %%
df.head()
# Out:
#                                     name  scores_teaching  scores_research  \
# 0                   University of Oxford             96.6            100.0
# 1                    Stanford University             99.0              NaN
# 2  Massachusetts Institute of Technology             98.6             96.2
# 3                     Harvard University             97.7              NaN
# 4                University of Cambridge             95.8            100.0
#
#    scores_citations  scores_industry_income  scores_international_outlook  \
# 0              99.0                    98.7                          97.5
# 1              99.6                   100.0                          87.0
# 2              99.7                   100.0                          93.8
# 3              99.4                    84.2                          90.8
# 4              98.0                    87.9                          97.4
#
# ...

# %%
df.head(10)
# Out:
#                                     name  scores_teaching  scores_research  \
# 0                   University of Oxford             96.6            100.0
# 1                    Stanford University             99.0              NaN
# 2  Massachusetts Institute of Technology             98.6             96.2
# 3                     Harvard University             97.7              NaN
# 4                University of Cambridge             95.8            100.0
# 5                   Princeton University             96.3             97.9
# 6     California Institute of Technology             96.6             98.0
# 7                Imperial College London             90.9             95.5
# 8     University of California, Berkeley             87.2             98.8
# 9                        Yale University             94.0             94.9
#
#    scores_citations  scores_industry_income  scores_international_outlook  \
# ...

# %%
df.tail()
# Out:
#                                        name  scores_teaching  scores_research  \
# 2668                       Zarqa University              NaN              NaN
# 2669                     Zhetysu University              NaN              NaN
# 2670  Zhytomyr Polytechnic State University              NaN              NaN
# 2671      Ziane Achour University of Djelfa              NaN              NaN
# 2672                    Ziauddin University              NaN              NaN
#
#       scores_citations  scores_industry_income  scores_international_outlook  \
# 2668               NaN                     NaN                           NaN
# 2669               NaN                     NaN                           NaN
# 2670               NaN                     NaN                           NaN
# 2671               NaN                     NaN                           NaN
# 2672               NaN                     NaN                           NaN
#
# ...

# %%
df.tail(8)
# Out:
#                                        name  scores_teaching  scores_research  \
# 2665                       Yaşar University              NaN              NaN
# 2666                York St John University              NaN              NaN
# 2667    Yusuf Maitama Sule University, Kano              NaN              NaN
# 2668                       Zarqa University              NaN              NaN
# 2669                     Zhetysu University              NaN              NaN
# 2670  Zhytomyr Polytechnic State University              NaN              NaN
# 2671      Ziane Achour University of Djelfa              NaN              NaN
# 2672                    Ziauddin University              NaN              NaN
#
#       scores_citations  scores_industry_income  scores_international_outlook  \
# 2665               NaN                     NaN                           NaN
# 2666               NaN                     NaN                           NaN
# ...

# %%
df.shape
# Out:
# (2673, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2673 entries, 0 to 2672
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          2673 non-null   object
#  1   scores_teaching               1904 non-null   float64
#  2   scores_research               1891 non-null   float64
#  3   scores_citations              1904 non-null   float64
#  4   scores_industry_income        1904 non-null   float64
#  5   scores_international_outlook  1904 non-null   float64
#  6   record_type                   2673 non-null   object
#  7   member_level                  2673 non-null   int64
#  8   location                      2673 non-null   object
#  9   stats_number_students         2673 non-null   object
#  10  stats_student_staff_ratio     2673 non-null   float64
#  11  stats_pc_intl_students        2673 non-null   object
# ...

# %%
df.describe()
# Out:
#        scores_teaching  scores_research  scores_citations  \
# count      1904.000000      1891.000000       1904.000000
# mean         29.060662        23.191962         52.189706
# std          13.967201        16.346202         25.071342
# min           9.400000         4.600000          3.400000
# 25%          19.400000        11.800000         30.400000
# 50%          25.800000        17.200000         52.400000
# 75%          34.500000        29.550000         73.225000
# max          99.000000       100.000000         99.700000
#
#        scores_industry_income  scores_international_outlook  member_level  \
# count             1904.000000                   1904.000000   2673.000000
# mean                47.057405                     49.907143      0.550318
# std                 26.150454                     21.828249      2.231166
# min                 15.600000                     16.100000      0.000000
# ...

# %%
df.scores_research.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.boxplot(df.scores_research)
# Out:
# <Axes: ylabel='scores_research'>

# %%
df = df[df.scores_research<=40]

# %%
df.shape
# Out:
# (1652, 17)

# %%
df.scores_research.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.boxplot(df.scores_research)
# Out:
# <Axes: ylabel='scores_research'>

# %%
df.head()
# Out:
#                      name  scores_teaching  scores_research  scores_citations  \
# 182  University of Geneva             41.8             38.0              86.7
# 189    Cardiff University             35.5             39.6              91.9
# 191      Tufts University             51.5             35.0              87.5
# 193   University of Macau             38.4             38.1              90.3
# 197    Indiana University             47.3             38.4              84.9
#
#      scores_industry_income  scores_international_outlook     record_type  \
# 182                    80.7                          97.1  master_account
# 189                    70.4                          92.5  master_account
# 191                    71.7                          62.8         private
# 193                    61.9                          93.7  master_account
# 197                    85.8                          64.7          public
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("World University Rankings.csv")

# %%
df = df[['scores_research']]

# %%
df.head()
# Out:
#    scores_research
# 0            100.0
# 1              NaN
# 2             96.2
# 3              NaN
# 4            100.0

# %%
df.fillna(df.median())
# Out:
#       scores_research
# 0               100.0
# 1                17.2
# 2                96.2
# 3                17.2
# 4               100.0
# ...               ...
# 2668             17.2
# 2669             17.2
# 2670             17.2
# 2671             17.2
# 2672             17.2
#
# [2673 rows x 1 columns]

# %%
df.isna().sum()
# Out:
# scores_research    782
# dtype: int64

# %%
df.isin([0]).sum()
# Out:
# scores_research    0
# dtype: int64
